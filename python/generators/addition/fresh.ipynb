# %%
import sys
sys.path.append('/Users/jd/Development/automath/python')
from addition_generator import AdditionGenerator
gen = AdditionGenerator(numbers=[99, 1])
gen.generate_problems()
gen.pack_for_json()

import json
parsed = json.loads(gen.json_output)
print(json.dumps(parsed, indent=4))
# Out:
# {
#     "problem_id": {
#         "1": "a8db40dffb"
#     },
#     "problem_nospace": {
#         "1": "99+1"
#     },
#     "problem_space": {
#         "1": "99 + 1"
#     },
#     "grade_level": 2,
#     "param_grid_carry_exposed": {
#         "a8db40dffb_full_01": {
#             "problem_instance": "a8db40dffb_full_01",
#             "problem_id": {
#                 "1": "a8db40dffb"
#             },
#             "param_type": "full",
#             "param_num": "01",
#             "num_parameters": 5,
#             "num_steps": 3,
#             "level_num": null,
#             "sub_level_score": 9,
#             "param_grid": {
#                 "C|": [
#                     "A",
#                     "B",
#                     " "
#                 ],
#                 "1|": [
#                     " ",
#                     "9",
#                     "9"
#                 ],
#                 "2|": [
#                     " ",
#                     "+",
# ...
