# %%
import unittest
import numpy as np
from pprint import pformat  # For cleaner diff output
import os
import sys
# %cd -q ..
from addition_generator import AdditionGenerator  # Adjust this import as needed

def scrap():
    generator = AdditionGenerator(numbers=[2, 5])
    generator.build_grid()
    generator.solve_grid()
    generator.parameterize_grid()
    generator.step_mapping_grid() # modifies step_map
    generator.generate_steps_init() # modifies step_human_init  |  This is correct.  Check generate_steps() for the error  
    generator.generate_steps() # modifies step_human 
    generator.build_lookup_table()
    return generator.lookup_table
test = scrap()
test
# Out:
#        param_grid solved_grid step_map  \
# (0, 0)
# (0, 1)
# (0, 2)
# (1, 0)
# (1, 1)
# (1, 2)          2           2        1
# (2, 0)          +           +
# (2, 1)
# (2, 2)          5           5        1
# (3, 0)
# (3, 1)
# (3, 2)          A           7        1
#
#                                                step_human
# (0, 0)                                               None
# (0, 1)                                               None
# (0, 2)                                               None
# (1, 0)                                               None
# (1, 1)                                               None
# (1, 2)  Step 1\nOperation: Add 2 and 5\nCalculation: 2...
# (2, 0)                                               None
# (2, 1)                                               None
# (2, 2)  Step 1\nOperation: Add 2 and 5\nCalculation: 2...
# (3, 0)                                               None
# (3, 1)                                               None
# ...
